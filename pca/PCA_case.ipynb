# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_lfw_people

# %%
#获取sklearn中的人脸数据集
faces = fetch_lfw_people()
faces.data.shape
#13233条信息，2914个特征点
faces.images.shape
#62*47的图像平面
# Out:
# (13233, 62, 47)

# %%
#随机获取25张人脸
import numpy as np

random_indexs = np.random.permutation(len(faces.data))
X = faces.data[random_indexs]
example_faces = X[:25,:]
example_faces.shape
# Out:
# (25, 2914)

# %%
#绘制人脸
def plot_digits(data):
    fig,axes = plt.subplots(5,5,figsize=(10,10),
    subplot_kw={'xticks':[],'yticks':[]},
    gridspec_kw=dict(hspace=0.1,wspace=0.1))
    for i,ax in enumerate(axes.flat):
        ax.imshow(data[i].reshape(62,47),cmap='bone')

plot_digits(example_faces)
peoples_name = faces.target_names #人脸名
print(len(faces.target_names)) #获取总人数
#总人数为5749
# Out:
# 5749

# %%
#使用随机的方式来求解出PCA
X,y = faces.data,faces.target
from sklearn.decomposition import PCA
pca = PCA(svd_solver='randomized')
pca.fit(X)
pca.components_.shape
#绘制特征脸
plot_digits(pca.components_)
